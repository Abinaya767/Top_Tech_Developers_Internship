# %%
import pandas as pd

# %%
df=pd.read_excel("/content/Day_6 Sample_dataSet.xlsx")

# %%
df
# Out:
#     Id Student_Name                Email  Gender  weekly_self_study_hours  \
# 0    1          Abi       abi1@gmail.com  Female                       10
# 1    2          Ram       ram2@gmail.com    Male                        4
# 2    3        Priya     priya3@gmail.com  Female                        1
# 3    4        Divya     divya4@gmail.com  Female                        5
# 4    5        Kavin     kavin5@gmail.com    Male                        3
# 5    6        Meena     meena6@gmail.com  Female                        6
# 6    7        Arjun     arjun7@gmail.com    Male                        2
# 7    8        Sneha     sneha8@gmail.com  Female                        4
# 8    9        Rahul     rahul9@gmail.com    Male                        1
# 9   10          Anu      anu10@gmail.com  Female                        5
# 10  11       Seeman   seeman11@gmail.com    Male                        3
# 11  12      Keerthi  keerthi12@gmail.com  Female                        2
# ...

# %%
df.head()
# Out:
#    Id Student_Name             Email  Gender  weekly_self_study_hours  \
# 0   1          Abi    abi1@gmail.com  Female                       10
# 1   2          Ram    ram2@gmail.com    Male                        4
# 2   3        Priya  priya3@gmail.com  Female                        1
# 3   4        Divya  divya4@gmail.com  Female                        5
# 4   5        Kavin  kavin5@gmail.com    Male                        3
#
#    math_score  history_score  physics_score  chemistry_score  biology_score  \
# 0         100             98             97               99            100
# 1          78             80             82               79             85
# 2          50             55             58               52             60
# 3          90             92             88               91             94
# 4          72             74             70               73             76
#
#    english_score  geography_score Grade
# 0            100               98    A+
# ...

# %%
df.tail()
# Out:
#     Id Student_Name                Email  Gender  weekly_self_study_hours  \
# 15  16      Lavanya  lavanya16@gmail.com  Female                        5
# 16  17         Ajay     ajay17@gmail.com    Male                        2
# 17  18        Pooja    pooja18@gmail.com  Female                        3
# 18  19       Sanjay   sanjay19@gmail.com    Male                        4
# 19  20        Rekha    rekha20@gmail.com  Female                        6
#
#     math_score  history_score  physics_score  chemistry_score  biology_score  \
# 15          93             91             94               92             96
# 16          62             64             66               63             67
# 17          76             78             74               77             79
# 18          82             85             83               81             86
# 19          89             90             91               88             92
#
#     english_score  geography_score Grade
# ...

# %%
df.shape
# Out:
# (20, 13)

# %%
df.columns
# Out:
# Index(['Id', 'Student_Name', 'Email', 'Gender', 'weekly_self_study_hours',
#        'math_score', 'history_score', 'physics_score', 'chemistry_score',
#        'biology_score', 'english_score', 'geography_score', 'Grade'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Id                          int64
# Student_Name               object
# Email                      object
# Gender                     object
# weekly_self_study_hours     int64
# math_score                  int64
# history_score               int64
# physics_score               int64
# chemistry_score             int64
# biology_score               int64
# english_score               int64
# geography_score             int64
# Grade                      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Id                       20 non-null     int64
#  1   Student_Name             20 non-null     object
#  2   Email                    20 non-null     object
#  3   Gender                   20 non-null     object
#  4   weekly_self_study_hours  20 non-null     int64
#  5   math_score               20 non-null     int64
#  6   history_score            20 non-null     int64
#  7   physics_score            20 non-null     int64
#  8   chemistry_score          20 non-null     int64
#  9   biology_score            20 non-null     int64
#  10  english_score            20 non-null     int64
#  11  geography_score          20 non-null     int64
#  12  Grade                    20 non-null     object
# dtypes: int64(9), object(4)
# memory usage: 2.2+ KB

# %%
df["math_score"].sum()
# Out:
# np.int64(1517)

# %%
df["physics_score"].mean()
# Out:
# np.float64(77.05)

# %%
df["chemistry_score"].min()
# Out:
# 46

# %%
df["biology_score"].max()
# Out:
# 100

# %%
df["Student_Name"].unique()
# Out:
# array(['Abi', 'Ram', 'Priya', 'Divya', 'Kavin', 'Meena', 'Arjun', 'Sneha',
#        'Rahul', 'Anu', 'Seeman', 'Keerthi', 'Vicky', 'Nisha', 'Hari',
#        'Lavanya', 'Ajay', 'Pooja', 'Sanjay', 'Rekha'], dtype=object)

# %%
df.drop("Student_Name",axis=1)
# Out:
#     Id                Email  Gender  weekly_self_study_hours  math_score  \
# 0    1       abi1@gmail.com  Female                       10         100
# 1    2       ram2@gmail.com    Male                        4          78
# 2    3     priya3@gmail.com  Female                        1          50
# 3    4     divya4@gmail.com  Female                        5          90
# 4    5     kavin5@gmail.com    Male                        3          72
# 5    6     meena6@gmail.com  Female                        6          88
# 6    7     arjun7@gmail.com    Male                        2          61
# 7    8     sneha8@gmail.com  Female                        4          79
# 8    9     rahul9@gmail.com    Male                        1          45
# 9   10      anu10@gmail.com  Female                        5          91
# 10  11   seeman11@gmail.com    Male                        3          74
# 11  12  keerthi12@gmail.com  Female                        2          67
# ...

# %%
df.rename(columns={"Student_Name":"Name"})
# Out:
#     Id     Name                Email  Gender  weekly_self_study_hours  \
# 0    1      Abi       abi1@gmail.com  Female                       10
# 1    2      Ram       ram2@gmail.com    Male                        4
# 2    3    Priya     priya3@gmail.com  Female                        1
# 3    4    Divya     divya4@gmail.com  Female                        5
# 4    5    Kavin     kavin5@gmail.com    Male                        3
# 5    6    Meena     meena6@gmail.com  Female                        6
# 6    7    Arjun     arjun7@gmail.com    Male                        2
# 7    8    Sneha     sneha8@gmail.com  Female                        4
# 8    9    Rahul     rahul9@gmail.com    Male                        1
# 9   10      Anu      anu10@gmail.com  Female                        5
# 10  11   Seeman   seeman11@gmail.com    Male                        3
# 11  12  Keerthi  keerthi12@gmail.com  Female                        2
# ...

# %%
df.query("math_score>90")
# Out:
#     Id Student_Name                Email  Gender  weekly_self_study_hours  \
# 0    1          Abi       abi1@gmail.com  Female                       10
# 9   10          Anu      anu10@gmail.com  Female                        5
# 15  16      Lavanya  lavanya16@gmail.com  Female                        5
#
#     math_score  history_score  physics_score  chemistry_score  biology_score  \
# 0          100             98             97               99            100
# 9           91             89             92               90             95
# 15          93             91             94               92             96
#
#     english_score  geography_score Grade
# 0             100               98    A+
# 9              93               94    A+
# 15             95               97    A+

# %%
df[df["geography_score"]==90]
# Out:
#     Id Student_Name              Email  Gender  weekly_self_study_hours  \
# 19  20        Rekha  rekha20@gmail.com  Female                        6
#
#     math_score  history_score  physics_score  chemistry_score  biology_score  \
# 19          89             90             91               88             92
#
#     english_score  geography_score Grade
# 19             93               90    A+

# %%
df["Student_Name"]
# Out:
# 0         Abi
# 1         Ram
# 2       Priya
# 3       Divya
# 4       Kavin
# 5       Meena
# 6       Arjun
# 7       Sneha
# 8       Rahul
# 9         Anu
# 10     Seeman
# 11    Keerthi
# 12      Vicky
# 13      Nisha
# 14       Hari
# 15    Lavanya
# 16       Ajay
# 17      Pooja
# 18     Sanjay
# 19      Rekha
# Name: Student_Name, dtype: object

# %%
df[["Student_Name","Id"]]
# Out:
#    Student_Name  Id
# 0           Abi   1
# 1           Ram   2
# 2         Priya   3
# 3         Divya   4
# 4         Kavin   5
# 5         Meena   6
# 6         Arjun   7
# 7         Sneha   8
# 8         Rahul   9
# 9           Anu  10
# 10       Seeman  11
# 11      Keerthi  12
# 12        Vicky  13
# 13        Nisha  14
# 14         Hari  15
# 15      Lavanya  16
# 16         Ajay  17
# 17        Pooja  18
# 18       Sanjay  19
# 19        Rekha  20

# %%
df["Student_Name"].str.upper()
# Out:
# 0         ABI
# 1         RAM
# 2       PRIYA
# 3       DIVYA
# 4       KAVIN
# 5       MEENA
# 6       ARJUN
# 7       SNEHA
# 8       RAHUL
# 9         ANU
# 10     SEEMAN
# 11    KEERTHI
# 12      VICKY
# 13      NISHA
# 14       HARI
# 15    LAVANYA
# 16       AJAY
# 17      POOJA
# 18     SANJAY
# 19      REKHA
# Name: Student_Name, dtype: object

# %%
df["Student_Name"].str.swapcase()
# Out:
# 0         aBI
# 1         rAM
# 2       pRIYA
# 3       dIVYA
# 4       kAVIN
# 5       mEENA
# 6       aRJUN
# 7       sNEHA
# 8       rAHUL
# 9         aNU
# 10     sEEMAN
# 11    kEERTHI
# 12      vICKY
# 13      nISHA
# 14       hARI
# 15    lAVANYA
# 16       aJAY
# 17      pOOJA
# 18     sANJAY
# 19      rEKHA
# Name: Student_Name, dtype: object

# %%
df[df["history_score"].between(80,90)]
# Out:
#     Id Student_Name               Email  Gender  weekly_self_study_hours  \
# 1    2          Ram      ram2@gmail.com    Male                        4
# 5    6        Meena    meena6@gmail.com  Female                        6
# 7    8        Sneha    sneha8@gmail.com  Female                        4
# 9   10          Anu     anu10@gmail.com  Female                        5
# 12  13        Vicky   vicky13@gmail.com    Male                        6
# 13  14        Nisha   nisha14@gmail.com  Female                        4
# 18  19       Sanjay  sanjay19@gmail.com    Male                        4
# 19  20        Rekha   rekha20@gmail.com  Female                        6
#
#     math_score  history_score  physics_score  chemistry_score  biology_score  \
# 1           78             80             82               79             85
# 5           88             84             86               90             89
# 7           79             82             80               78             84
# ...

# %%
df["Student_Name"].str.len()
# Out:
# 0     3
# 1     3
# 2     5
# 3     5
# 4     5
# 5     5
# 6     5
# 7     5
# 8     5
# 9     3
# 10    6
# 11    7
# 12    5
# 13    5
# 14    4
# 15    7
# 16    4
# 17    5
# 18    6
# 19    5
# Name: Student_Name, dtype: int64

# %%
df["Student_Name"].str.contains("A")
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# Name: Student_Name, dtype: bool

# %%
df["Student_Name"].str.startswith("A")
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16     True
# 17    False
# 18    False
# 19    False
# Name: Student_Name, dtype: bool

# %%
df["Student_Name"].str.endswith("a")
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15     True
# 16    False
# 17     True
# 18    False
# 19     True
# Name: Student_Name, dtype: bool

# %%
df1=pd.read_csv("/content/student-scores_DATASET(cleaned).csv")

# %%
df1
# Out:
#         Id  weekly_self_study_hours  math_score  history_score  physics_score  \
# 0        1                       27          73             81             93
# 1        2                       47          90             86             96
# 2        3                       13          81             97             95
# 3        4                        3          71             74             88
# 4        5                       10          84             77             65
# ...    ...                      ...         ...            ...            ...
# 1494  1495                       15          85             76             94
# 1495  1496                       30          80             84             82
# 1496  1497                       31          99             61             91
# 1497  1498                       23          70             91             81
# 1498  1499                       23          62             72             78
#
# ...

# %%
pd.merge(df,df1,on="Id")
# Out:
#     Id Student_Name              Email_x Gender_x  weekly_self_study_hours_x  \
# 0    1          Abi       abi1@gmail.com   Female                         10
# 1    2          Ram       ram2@gmail.com     Male                          4
# 2    3        Priya     priya3@gmail.com   Female                          1
# 3    4        Divya     divya4@gmail.com   Female                          5
# 4    5        Kavin     kavin5@gmail.com     Male                          3
# 5    6        Meena     meena6@gmail.com   Female                          6
# 6    7        Arjun     arjun7@gmail.com     Male                          2
# 7    8        Sneha     sneha8@gmail.com   Female                          4
# 8    9        Rahul     rahul9@gmail.com     Male                          1
# 9   10          Anu      anu10@gmail.com   Female                          5
# 10  11       Seeman   seeman11@gmail.com     Male                          3
# ...

# %%
df["math_score"].astype(float)
# Out:
# 0     100.0
# 1      78.0
# 2      50.0
# 3      90.0
# 4      72.0
# 5      88.0
# 6      61.0
# 7      79.0
# 8      45.0
# 9      91.0
# 10     74.0
# 11     67.0
# 12     85.0
# 13     80.0
# 14     55.0
# 15     93.0
# 16     62.0
# 17     76.0
# 18     82.0
# 19     89.0
# Name: math_score, dtype: float64

# %%
print(df.join(df1,lsuffix="_left",rsuffix="_right"))
# Out:
#     Id_left  Age Student_Name           Email_left Gender_left  \
# 0         1   20          Abi       abi1@gmail.com      Female
# 1         2   20          Ram       ram2@gmail.com        Male
# 2         3   20        Priya     priya3@gmail.com      Female
# 3         4   20        Divya     divya4@gmail.com      Female
# 4         5   20        Kavin     kavin5@gmail.com        Male
# 5         6   20        Meena     meena6@gmail.com      Female
# 6         7   20        Arjun     arjun7@gmail.com        Male
# 7         8   20        Sneha     sneha8@gmail.com      Female
# 8         9   20        Rahul     rahul9@gmail.com        Male
# 9        10   20          Anu      anu10@gmail.com      Female
# 10       11   20       Seeman   seeman11@gmail.com        Male
# 11       12   20      Keerthi  keerthi12@gmail.com      Female
# 12       13   20        Vicky    vicky13@gmail.com        Male
# 13       14   20        Nisha    nisha14@gmail.com      Female
# ...

# %%
pd.concat([df1,df2])
# Out:
#         Id Student_Name                  Email  Gender  \
# 0        1          Abi         abi1@gmail.com  Female
# 1        2          Ram         ram2@gmail.com    Male
# 2        3        Priya       priya3@gmail.com  Female
# 3        4        Divya       divya4@gmail.com  Female
# 4        5        Kavin       kavin5@gmail.com    Male
# ...    ...          ...                    ...     ...
# 1494  1495          NaN  student1495@gmail.com    Male
# 1495  1496          NaN  student1496@gmail.com    Male
# 1496  1497          NaN  student1497@gmail.com    Male
# 1497  1498          NaN  student1498@gmail.com  Female
# 1498  1499          NaN  student1499@gmail.com  Female
#
#       weekly_self_study_hours  math_score  history_score  physics_score  \
# 0                          10         100             98             97
# 1                           4          78             80             82
# 2                           1          50             55             58
# ...

# %%
df["Student_Name"]
# Out:
# 0         Abi
# 1         Ram
# 2       Priya
# 3       Divya
# 4       Kavin
# 5       Meena
# 6       Arjun
# 7       Sneha
# 8       Rahul
# 9         Anu
# 10     Seeman
# 11    Keerthi
# 12      Vicky
# 13      Nisha
# 14       Hari
# 15    Lavanya
# 16       Ajay
# 17      Pooja
# 18     Sanjay
# 19      Rekha
# Name: Student_Name, dtype: object

# %%
df.fillna(0)
# Out:
#     Id Student_Name                Email  Gender  weekly_self_study_hours  \
# 0    1          Abi       abi1@gmail.com  Female                       10
# 1    2          Ram       ram2@gmail.com    Male                        4
# 2    3        Priya     priya3@gmail.com  Female                        1
# 3    4        Divya     divya4@gmail.com  Female                        5
# 4    5        Kavin     kavin5@gmail.com    Male                        3
# 5    6        Meena     meena6@gmail.com  Female                        6
# 6    7        Arjun     arjun7@gmail.com    Male                        2
# 7    8        Sneha     sneha8@gmail.com  Female                        4
# 8    9        Rahul     rahul9@gmail.com    Male                        1
# 9   10          Anu      anu10@gmail.com  Female                        5
# 10  11       Seeman   seeman11@gmail.com    Male                        3
# 11  12      Keerthi  keerthi12@gmail.com  Female                        2
# ...

# %%
df.sort_values("math_score")
# Out:
#     Id Student_Name                Email  Gender  weekly_self_study_hours  \
# 8    9        Rahul     rahul9@gmail.com    Male                        1
# 2    3        Priya     priya3@gmail.com  Female                        1
# 14  15         Hari     hari15@gmail.com    Male                        1
# 6    7        Arjun     arjun7@gmail.com    Male                        2
# 16  17         Ajay     ajay17@gmail.com    Male                        2
# 11  12      Keerthi  keerthi12@gmail.com  Female                        2
# 4    5        Kavin     kavin5@gmail.com    Male                        3
# 10  11       Seeman   seeman11@gmail.com    Male                        3
# 17  18        Pooja    pooja18@gmail.com  Female                        3
# 1    2          Ram       ram2@gmail.com    Male                        4
# 7    8        Sneha     sneha8@gmail.com  Female                        4
# 13  14        Nisha    nisha14@gmail.com  Female                        4
# ...

# %%
df.isnull()
# Out:
#        Id  Student_Name  Email  Gender  weekly_self_study_hours  math_score  \
# 0   False         False  False   False                    False       False
# 1   False         False  False   False                    False       False
# 2   False         False  False   False                    False       False
# 3   False         False  False   False                    False       False
# 4   False         False  False   False                    False       False
# 5   False         False  False   False                    False       False
# 6   False         False  False   False                    False       False
# 7   False         False  False   False                    False       False
# 8   False         False  False   False                    False       False
# 9   False         False  False   False                    False       False
# 10  False         False  False   False                    False       False
# ...

# %%
df.size
# Out:
# 260

# %%
df.insert(1,"Age",[20]*20)

# %%
df
# Out:
#     Id  Age Student_Name                Email  Gender  \
# 0    1   20          Abi       abi1@gmail.com  Female
# 1    2   20          Ram       ram2@gmail.com    Male
# 2    3   20        Priya     priya3@gmail.com  Female
# 3    4   20        Divya     divya4@gmail.com  Female
# 4    5   20        Kavin     kavin5@gmail.com    Male
# 5    6   20        Meena     meena6@gmail.com  Female
# 6    7   20        Arjun     arjun7@gmail.com    Male
# 7    8   20        Sneha     sneha8@gmail.com  Female
# 8    9   20        Rahul     rahul9@gmail.com    Male
# 9   10   20          Anu      anu10@gmail.com  Female
# 10  11   20       Seeman   seeman11@gmail.com    Male
# 11  12   20      Keerthi  keerthi12@gmail.com  Female
# 12  13   20        Vicky    vicky13@gmail.com    Male
# 13  14   20        Nisha    nisha14@gmail.com  Female
# 14  15   20         Hari     hari15@gmail.com    Male
# 15  16   20      Lavanya  lavanya16@gmail.com  Female
# ...

# %%
df.replace(90,100)
# Out:
#     Id  Age Student_Name                Email  Gender  \
# 0    1   20          Abi       abi1@gmail.com  Female
# 1    2   20          Ram       ram2@gmail.com    Male
# 2    3   20        Priya     priya3@gmail.com  Female
# 3    4   20        Divya     divya4@gmail.com  Female
# 4    5   20        Kavin     kavin5@gmail.com    Male
# 5    6   20        Meena     meena6@gmail.com  Female
# 6    7   20        Arjun     arjun7@gmail.com    Male
# 7    8   20        Sneha     sneha8@gmail.com  Female
# 8    9   20        Rahul     rahul9@gmail.com    Male
# 9   10   20          Anu      anu10@gmail.com  Female
# 10  11   20       Seeman   seeman11@gmail.com    Male
# 11  12   20      Keerthi  keerthi12@gmail.com  Female
# 12  13   20        Vicky    vicky13@gmail.com    Male
# 13  14   20        Nisha    nisha14@gmail.com  Female
# 14  15   20         Hari     hari15@gmail.com    Male
# 15  16   20      Lavanya  lavanya16@gmail.com  Female
# ...

# %%
df=df.assign(Age=[25]*20)

# %%
df
# Out:
#     Id  Age Student_Name                Email  Gender  \
# 0    1   25          Abi       abi1@gmail.com  Female
# 1    2   25          Ram       ram2@gmail.com    Male
# 2    3   25        Priya     priya3@gmail.com  Female
# 3    4   25        Divya     divya4@gmail.com  Female
# 4    5   25        Kavin     kavin5@gmail.com    Male
# 5    6   25        Meena     meena6@gmail.com  Female
# 6    7   25        Arjun     arjun7@gmail.com    Male
# 7    8   25        Sneha     sneha8@gmail.com  Female
# 8    9   25        Rahul     rahul9@gmail.com    Male
# 9   10   25          Anu      anu10@gmail.com  Female
# 10  11   25       Seeman   seeman11@gmail.com    Male
# 11  12   25      Keerthi  keerthi12@gmail.com  Female
# 12  13   25        Vicky    vicky13@gmail.com    Male
# 13  14   25        Nisha    nisha14@gmail.com  Female
# 14  15   25         Hari     hari15@gmail.com    Male
# 15  16   25      Lavanya  lavanya16@gmail.com  Female
# ...
