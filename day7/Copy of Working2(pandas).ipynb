# %%
import pandas as pd

# %%
df= pd.read_csv("/content/student-scores_DATASET(cleaned).csv")

# %%
df
# Out:
#         Id  weekly_self_study_hours  math_score  history_score  physics_score  \
# 0        1                       27          73             81             93
# 1        2                       47          90             86             96
# 2        3                       13          81             97             95
# 3        4                        3          71             74             88
# 4        5                       10          84             77             65
# ...    ...                      ...         ...            ...            ...
# 1494  1495                       15          85             76             94
# 1495  1496                       30          80             84             82
# 1496  1497                       31          99             61             91
# 1497  1498                       23          70             91             81
# 1498  1499                       23          62             72             78
#
# ...

# %%
df.head()
# Out:
#    Id  weekly_self_study_hours  math_score  history_score  physics_score  \
# 0   1                       27          73             81             93
# 1   2                       47          90             86             96
# 2   3                       13          81             97             95
# 3   4                        3          71             74             88
# 4   5                       10          84             77             65
#
#    chemistry_score  biology_score  english_score  geography_score      Grade  \
# 0               97             63             80               87       Good
# 1              100             90             88               90  Excellent
# 2               96             65             77               94       Good
# 3               80             89             63               86       Good
# 4               65             80             74               76       Good
#
#    Gender               Email
# 0    Male  student1@gmail.com
# ...

# %%
df.tail()
# Out:
#         Id  weekly_self_study_hours  math_score  history_score  physics_score  \
# 1494  1495                       15          85             76             94
# 1495  1496                       30          80             84             82
# 1496  1497                       31          99             61             91
# 1497  1498                       23          70             91             81
# 1498  1499                       23          62             72             78
#
#       chemistry_score  biology_score  english_score  geography_score Grade  \
# 1494               89             85             83               80  Good
# 1495               69             91             80               96  Good
# 1496               73             89             62               82  Good
# 1497               61             64             93               96  Good
# 1498               96             70             74               72  Good
#
#       Gender                  Email
# ...

# %%
df.shape
# Out:
# (1499, 12)

# %%
df.columns
# Out:
# Index(['Id', 'weekly_self_study_hours', 'math_score', 'history_score',
#        'physics_score', 'chemistry_score', 'biology_score', 'english_score',
#        'geography_score', 'Grade', 'Gender', 'Email'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Id                          int64
# weekly_self_study_hours     int64
# math_score                  int64
# history_score               int64
# physics_score               int64
# chemistry_score             int64
# biology_score               int64
# english_score               int64
# geography_score             int64
# Grade                      object
# Gender                     object
# Email                      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1499 entries, 0 to 1498
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Id                       1499 non-null   int64
#  1   weekly_self_study_hours  1499 non-null   int64
#  2   math_score               1499 non-null   int64
#  3   history_score            1499 non-null   int64
#  4   physics_score            1499 non-null   int64
#  5   chemistry_score          1499 non-null   int64
#  6   biology_score            1499 non-null   int64
#  7   english_score            1499 non-null   int64
#  8   geography_score          1499 non-null   int64
#  9   Grade                    1499 non-null   object
#  10  Gender                   1499 non-null   object
#  11  Email                    1499 non-null   object
# dtypes: int64(9), object(3)
# memory usage: 140.7+ KB

# %%
df.describe()
# Out:
#                Id  weekly_self_study_hours   math_score  history_score  \
# count  1499.00000              1499.000000  1499.000000    1499.000000
# mean    750.00000                17.779186    83.497665      80.075384
# std     432.86834                12.044253    13.278338      12.648754
# min       1.00000                 0.000000    40.000000      50.000000
# 25%     375.50000                 5.000000    76.500000      69.000000
# 50%     750.00000                18.000000    87.000000      81.000000
# 75%    1124.50000                28.000000    94.000000      91.000000
# max    1499.00000                50.000000   100.000000     100.000000
#
#        physics_score  chemistry_score  biology_score  english_score  \
# count    1499.000000      1499.000000    1499.000000    1499.000000
# mean       81.386925        79.939293      79.176117      81.354903
# std        12.541562        12.771105      13.816978      11.952878
# ...

# %%
df.isnull()
# Out:
#          Id  weekly_self_study_hours  math_score  history_score  \
# 0     False                    False       False          False
# 1     False                    False       False          False
# 2     False                    False       False          False
# 3     False                    False       False          False
# 4     False                    False       False          False
# ...     ...                      ...         ...            ...
# 1494  False                    False       False          False
# 1495  False                    False       False          False
# 1496  False                    False       False          False
# 1497  False                    False       False          False
# 1498  False                    False       False          False
#
#       physics_score  chemistry_score  biology_score  english_score  \
# 0             False            False          False          False
# ...

# %%
df["math_score"].sum()
# Out:
# np.int64(125163)

# %%
df["weekly_self_study_hours"].mean()
# Out:
# np.float64(17.77918612408272)

# %%
df["Gender"].mode()
# Out:
# 0    Female
# Name: Gender, dtype: object

# %%
df["history_score"].max()
# Out:
# 100

# %%
df["physics_score"].min()
# Out:
# 50

# %%
df["Id"].count()
# Out:
# np.int64(1499)

# %%
df["geography_score"].std()
# Out:
# 11.728970481124724

# %%
df["english_score"].var()
# Out:
# 142.87128935979777

# %%
df["Grade"].unique()
# Out:
# array(['Good', 'Excellent', 'Average'], dtype=object)

# %%
df.sort_values("chemistry_score")
# Out:
#         Id  weekly_self_study_hours  math_score  history_score  physics_score  \
# 41      42                        4          65             55             66
# 1163  1164                        4          71             89             63
# 819    820                        2          46             71             60
# 644    645                        0          82             74             92
# 1340  1341                        0          79             67             72
# ...    ...                      ...         ...            ...            ...
# 361    362                       30         100             86             81
# 355    356                        5         100             58             58
# 1102  1103                       32          78             92             77
# 1        2                       47          90             86             96
# 1492  1493                       21         100             82             84
#
# ...

# %%
df.sort_index()
# Out:
#         Id  weekly_self_study_hours  math_score  history_score  physics_score  \
# 0        1                       27          73             81             93
# 1        2                       47          90             86             96
# 2        3                       13          81             97             95
# 3        4                        3          71             74             88
# 4        5                       10          84             77             65
# ...    ...                      ...         ...            ...            ...
# 1494  1495                       15          85             76             94
# 1495  1496                       30          80             84             82
# 1496  1497                       31          99             61             91
# 1497  1498                       23          70             91             81
# 1498  1499                       23          62             72             78
#
# ...

# %%
df.drop("Email",axis=1)
# Out:
#         Id  weekly_self_study_hours  math_score  history_score  physics_score  \
# 0        1                       27          73             81             93
# 1        2                       47          90             86             96
# 2        3                       13          81             97             95
# 3        4                        3          71             74             88
# 4        5                       10          84             77             65
# ...    ...                      ...         ...            ...            ...
# 1494  1495                       15          85             76             94
# 1495  1496                       30          80             84             82
# 1496  1497                       31          99             61             91
# 1497  1498                       23          70             91             81
# 1498  1499                       23          62             72             78
#
# ...

# %%
df.drop_duplicates()
# Out:
#         Id  weekly_self_study_hours  math_score  history_score  physics_score  \
# 0        1                       27          73             81             93
# 1        2                       47          90             86             96
# 2        3                       13          81             97             95
# 3        4                        3          71             74             88
# 4        5                       10          84             77             65
# ...    ...                      ...         ...            ...            ...
# 1494  1495                       15          85             76             94
# 1495  1496                       30          80             84             82
# 1496  1497                       31          99             61             91
# 1497  1498                       23          70             91             81
# 1498  1499                       23          62             72             78
#
# ...

# %%
df.rename(columns={"weekly_self_study_hours":"Study_Hours"})
# Out:
#         Id  Study_Hours  math_score  history_score  physics_score  \
# 0        1           27          73             81             93
# 1        2           47          90             86             96
# 2        3           13          81             97             95
# 3        4            3          71             74             88
# 4        5           10          84             77             65
# ...    ...          ...         ...            ...            ...
# 1494  1495           15          85             76             94
# 1495  1496           30          80             84             82
# 1496  1497           31          99             61             91
# 1497  1498           23          70             91             81
# 1498  1499           23          62             72             78
#
#       chemistry_score  biology_score  english_score  geography_score  \
# 0                  97             63             80               87
# ...

# %%
df.insert(2,"Age",[20]*1499)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_404/3238204040.py in <cell line: 0>()
# ----> 1 df.insert(2,"Age",[20]*1499)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
#    5160             raise TypeError("loc must be int")
#
# ValueError: cannot insert Age, already exists

# %%
df
# Out:
#         Id  weekly_self_study_hours  Age  math_score  history_score  \
# 0        1                       27   20          73             81
# 1        2                       47   20          90             86
# 2        3                       13   20          81             97
# 3        4                        3   20          71             74
# 4        5                       10   20          84             77
# ...    ...                      ...  ...         ...            ...
# 1494  1495                       15   20          85             76
# 1495  1496                       30   20          80             84
# 1496  1497                       31   20          99             61
# 1497  1498                       23   20          70             91
# 1498  1499                       23   20          62             72
#
#       physics_score  chemistry_score  biology_score  english_score  \
# 0                93               97             63             80
# ...

# %%
df.replace(90,100)
# Out:
#         Id  weekly_self_study_hours  Age  math_score  history_score  \
# 0        1                       27   20          73             81
# 1        2                       47   20         100             86
# 2        3                       13   20          81             97
# 3        4                        3   20          71             74
# 4        5                       10   20          84             77
# ...    ...                      ...  ...         ...            ...
# 1494  1495                       15   20          85             76
# 1495  1496                       30   20          80             84
# 1496  1497                       31   20          99             61
# 1497  1498                       23   20          70             91
# 1498  1499                       23   20          62             72
#
#       physics_score  chemistry_score  biology_score  english_score  \
# 0                93               97             63             80
# ...

# %%
df.query("math_score>90")
# Out:
#         Id  weekly_self_study_hours  Age  math_score  history_score  \
# 5        6                       26   20          93            100
# 6        7                       23   20          99             96
# 7        8                       34   20          95             95
# 8        9                       25   20          94             68
# 9       10                       18   20          98             69
# ...    ...                      ...  ...         ...            ...
# 1488  1489                       27   20          96             92
# 1491  1492                        4   20          92             96
# 1492  1493                       21   20         100             82
# 1493  1494                       31   20          94             63
# 1496  1497                       31   20          99             61
#
#       physics_score  chemistry_score  biology_score  english_score  \
# 5                67               78             72             80
# ...

# %%
df.sample(1)
# Out:
#         Id  weekly_self_study_hours  Age  math_score  history_score  \
# 1355  1356                       11   20          76             82
#
#       physics_score  chemistry_score  biology_score  english_score  \
# 1355             74               79             81             93
#
#       geography_score Grade  Gender                  Email
# 1355               72  Good  Female  student1356@gmail.com

# %%
df.loc[0]
# Out:
# Id                                          1
# weekly_self_study_hours                    27
# Age                                        20
# math_score                                 73
# history_score                              81
# physics_score                              93
# chemistry_score                            97
# biology_score                              63
# english_score                              80
# geography_score                            87
# Grade                                    Good
# Gender                                   Male
# Email                      student1@gmail.com
# Name: 0, dtype: object

# %%
df.groupby("Id").sum()
# Out:
#       weekly_self_study_hours  Age  math_score  history_score  physics_score  \
# Id
# 1                          27   20          73             81             93
# 2                          47   20          90             86             96
# 3                          13   20          81             97             95
# 4                           3   20          71             74             88
# 5                          10   20          84             77             65
# ...                       ...  ...         ...            ...            ...
# 1495                       15   20          85             76             94
# 1496                       30   20          80             84             82
# 1497                       31   20          99             61             91
# 1498                       23   20          70             91             81
# 1499                       23   20          62             72             78
#
# ...

# %%
pd.concat([df,df])
# Out:
#         Id  weekly_self_study_hours  Age  math_score  history_score  \
# 0        1                       27   20          73             81
# 1        2                       47   20          90             86
# 2        3                       13   20          81             97
# 3        4                        3   20          71             74
# 4        5                       10   20          84             77
# ...    ...                      ...  ...         ...            ...
# 1494  1495                       15   20          85             76
# 1495  1496                       30   20          80             84
# 1496  1497                       31   20          99             61
# 1497  1498                       23   20          70             91
# 1498  1499                       23   20          62             72
#
#       physics_score  chemistry_score  biology_score  english_score  \
# 0                93               97             63             80
# ...

# %%
df2=pd.read_csv("/content/student-scores_DATASET(cleaned).csv")

# %%
df2
# Out:
#         Id  weekly_self_study_hours  math_score  history_score  physics_score  \
# 0        1                       27          73             81             93
# 1        2                       47          90             86             96
# 2        3                       13          81             97             95
# 3        4                        3          71             74             88
# 4        5                       10          84             77             65
# ...    ...                      ...         ...            ...            ...
# 1494  1495                       15          85             76             94
# 1495  1496                       30          80             84             82
# 1496  1497                       31          99             61             91
# 1497  1498                       23          70             91             81
# 1498  1499                       23          62             72             78
#
# ...

# %%
pd.merge(df,df2,on="Id")
# Out:
#         Id  weekly_self_study_hours_x  Age  math_score_x  history_score_x  \
# 0        1                         27   20            73               81
# 1        2                         47   20            90               86
# 2        3                         13   20            81               97
# 3        4                          3   20            71               74
# 4        5                         10   20            84               77
# ...    ...                        ...  ...           ...              ...
# 1494  1495                         15   20            85               76
# 1495  1496                         30   20            80               84
# 1496  1497                         31   20            99               61
# 1497  1498                         23   20            70               91
# 1498  1499                         23   20            62               72
#
#       physics_score_x  chemistry_score_x  biology_score_x  english_score_x  \
# ...

# %%
df["Age"].astype(float)
# Out:
# 0       20.0
# 1       20.0
# 2       20.0
# 3       20.0
# 4       20.0
#         ...
# 1494    20.0
# 1495    20.0
# 1496    20.0
# 1497    20.0
# 1498    20.0
# Name: Age, Length: 1499, dtype: float64

# %%
df.to_numpy()
# Out:
# array([[1, 27, 20, ..., 'Good', 'Male', 'student1@gmail.com'],
#        [2, 47, 20, ..., 'Excellent', 'Male', 'student2@gmail.com'],
#        [3, 13, 20, ..., 'Good', 'Female', 'student3@gmail.com'],
#        ...,
#        [1497, 31, 20, ..., 'Good', 'Male', 'student1497@gmail.com'],
#        [1498, 23, 20, ..., 'Good', 'Female', 'student1498@gmail.com'],
#        [1499, 23, 20, ..., 'Good', 'Female', 'student1499@gmail.com']],
#       dtype=object)

# %%
df[df["history_score"]>80]
# Out:
#         Id  weekly_self_study_hours  Age  math_score  history_score  \
# 0        1                       27   20          73             81
# 1        2                       47   20          90             86
# 2        3                       13   20          81             97
# 5        6                       26   20          93            100
# 6        7                       23   20          99             96
# ...    ...                      ...  ...         ...            ...
# 1489  1490                       29   20          90             84
# 1491  1492                        4   20          92             96
# 1492  1493                       21   20         100             82
# 1495  1496                       30   20          80             84
# 1497  1498                       23   20          70             91
#
#       physics_score  chemistry_score  biology_score  english_score  \
# 0                93               97             63             80
# ...

# %%
df[df["english_score"]==90]
# Out:
#         Id  weekly_self_study_hours  Age  math_score  history_score  \
# 13      14                        2   20          66             94
# 25      26                       22   20          92             86
# 26      27                       34   20         100             77
# 102    103                       29   20          76             87
# 110    111                       24   20          76             89
# 120    121                       13   20          66             90
# 134    135                        3   20          87             62
# 137    138                       11   20          79             97
# 152    153                       18   20          91            100
# 176    177                       15   20          97             92
# 190    191                        1   20          99             82
# 221    222                       22   20          95             87
# 222    223                       33   20          99             61
# ...

# %%
df["Email"]
# Out:
# 0          student1@gmail.com
# 1          student2@gmail.com
# 2          student3@gmail.com
# 3          student4@gmail.com
# 4          student5@gmail.com
#                 ...
# 1494    student1495@gmail.com
# 1495    student1496@gmail.com
# 1496    student1497@gmail.com
# 1497    student1498@gmail.com
# 1498    student1499@gmail.com
# Name: Email, Length: 1499, dtype: object

# %%
df[["Id","Gender"]]
# Out:
#         Id  Gender
# 0        1    Male
# 1        2    Male
# 2        3  Female
# 3        4  Female
# 4        5  Female
# ...    ...     ...
# 1494  1495    Male
# 1495  1496    Male
# 1496  1497    Male
# 1497  1498  Female
# 1498  1499  Female
#
# [1499 rows x 2 columns]

# %%
df[df["geography_score"].between(80,90)]
# Out:
#         Id  weekly_self_study_hours  Age  math_score  history_score  \
# 0        1                       27   20          73             81
# 1        2                       47   20          90             86
# 3        4                        3   20          71             74
# 5        6                       26   20          93            100
# 7        8                       34   20          95             95
# ...    ...                      ...  ...         ...            ...
# 1487  1488                        1   20          96             92
# 1490  1491                        4   20          85             57
# 1492  1493                       21   20         100             82
# 1494  1495                       15   20          85             76
# 1496  1497                       31   20          99             61
#
#       physics_score  chemistry_score  biology_score  english_score  \
# 0                93               97             63             80
# ...

# %%
df["Email"].str.upper()
# Out:
# 0          STUDENT1@GMAIL.COM
# 1          STUDENT2@GMAIL.COM
# 2          STUDENT3@GMAIL.COM
# 3          STUDENT4@GMAIL.COM
# 4          STUDENT5@GMAIL.COM
#                 ...
# 1494    STUDENT1495@GMAIL.COM
# 1495    STUDENT1496@GMAIL.COM
# 1496    STUDENT1497@GMAIL.COM
# 1497    STUDENT1498@GMAIL.COM
# 1498    STUDENT1499@GMAIL.COM
# Name: Email, Length: 1499, dtype: object

# %%
df["Gender"].str.title()
# Out:
# 0         Male
# 1         Male
# 2       Female
# 3       Female
# 4       Female
#          ...
# 1494      Male
# 1495      Male
# 1496      Male
# 1497    Female
# 1498    Female
# Name: Gender, Length: 1499, dtype: object

# %%
df["Email"].str.capitalize()
# Out:
# 0          Student1@gmail.com
# 1          Student2@gmail.com
# 2          Student3@gmail.com
# 3          Student4@gmail.com
# 4          Student5@gmail.com
#                 ...
# 1494    Student1495@gmail.com
# 1495    Student1496@gmail.com
# 1496    Student1497@gmail.com
# 1497    Student1498@gmail.com
# 1498    Student1499@gmail.com
# Name: Email, Length: 1499, dtype: object

# %%
df["Grade"].str.len()
# Out:
# 0       4
# 1       9
# 2       4
# 3       4
# 4       4
#        ..
# 1494    4
# 1495    4
# 1496    4
# 1497    4
# 1498    4
# Name: Grade, Length: 1499, dtype: int64

# %%
df["Grade"].str.contains("A")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1494    False
# 1495    False
# 1496    False
# 1497    False
# 1498    False
# Name: Grade, Length: 1499, dtype: bool

# %%
df["Grade"].str.startswith("G")
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 1494     True
# 1495     True
# 1496     True
# 1497     True
# 1498     True
# Name: Grade, Length: 1499, dtype: bool

# %%
df.drop_duplicates()
# Out:
#         Id  weekly_self_study_hours  Age  math_score  history_score  \
# 0        1                       27   20          73             81
# 1        2                       47   20          90             86
# 2        3                       13   20          81             97
# 3        4                        3   20          71             74
# 4        5                       10   20          84             77
# ...    ...                      ...  ...         ...            ...
# 1494  1495                       15   20          85             76
# 1495  1496                       30   20          80             84
# 1496  1497                       31   20          99             61
# 1497  1498                       23   20          70             91
# 1498  1499                       23   20          62             72
#
#       physics_score  chemistry_score  biology_score  english_score  \
# 0                93               97             63             80
# ...

# %%
df.copy()
# Out:
#         Id  weekly_self_study_hours  Age  math_score  history_score  \
# 0        1                       27   20          73             81
# 1        2                       47   20          90             86
# 2        3                       13   20          81             97
# 3        4                        3   20          71             74
# 4        5                       10   20          84             77
# ...    ...                      ...  ...         ...            ...
# 1494  1495                       15   20          85             76
# 1495  1496                       30   20          80             84
# 1496  1497                       31   20          99             61
# 1497  1498                       23   20          70             91
# 1498  1499                       23   20          62             72
#
#       physics_score  chemistry_score  biology_score  english_score  \
# 0                93               97             63             80
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1494    False
# 1495    False
# 1496    False
# 1497    False
# 1498    False
# Length: 1499, dtype: bool

# %%
df.fillna(0)
# Out:
#         Id  weekly_self_study_hours  Age  math_score  history_score  \
# 0        1                       27   20          73             81
# 1        2                       47   20          90             86
# 2        3                       13   20          81             97
# 3        4                        3   20          71             74
# 4        5                       10   20          84             77
# ...    ...                      ...  ...         ...            ...
# 1494  1495                       15   20          85             76
# 1495  1496                       30   20          80             84
# 1496  1497                       31   20          99             61
# 1497  1498                       23   20          70             91
# 1498  1499                       23   20          62             72
#
#       physics_score  chemistry_score  biology_score  english_score  \
# 0                93               97             63             80
# ...

# %%
df.set_index("Id")
# Out:
#       weekly_self_study_hours  Age  math_score  history_score  physics_score  \
# Id
# 1                          27   20          73             81             93
# 2                          47   20          90             86             96
# 3                          13   20          81             97             95
# 4                           3   20          71             74             88
# 5                          10   20          84             77             65
# ...                       ...  ...         ...            ...            ...
# 1495                       15   20          85             76             94
# 1496                       30   20          80             84             82
# 1497                       31   20          99             61             91
# 1498                       23   20          70             91             81
# 1499                       23   20          62             72             78
#
# ...

# %%
pd.Series([df])
# Out:
# 0            Id  weekly_self_study_hours  Age  math...
# dtype: object

# %%
df.nunique()
# Out:
# Id                         1499
# weekly_self_study_hours      49
# Age                           1
# math_score                   61
# history_score                51
# physics_score                49
# chemistry_score              51
# biology_score                68
# english_score                50
# geography_score              41
# Grade                         3
# Gender                        2
# Email                      1499
# dtype: int64
