# %%
import numpy as np
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
np.median([1,2,3])
# Out:
# np.float64(2.0)

# %%
np.sum([1,2,3])
# Out:
# np.int64(6)

# %%
np.mean([1,2,3])
# Out:
# np.float64(2.0)

# %%
np.median([1,2,3])
# Out:
# np.float64(2.0)

# %%
np.max([1,2,3])
# Out:
# np.int64(3)

# %%
np.min([1,2,3])
# Out:
# np.int64(1)

# %%
np.sqrt([1,4,9])
# Out:
# array([1., 2., 3.])

# %%
np.power([1,2,3],2)
# Out:
# array([1, 4, 9])

# %%
np.sort([3,1,2])
# Out:
# array([1, 2, 3])

# %%
np.append([1,2,3], 4)
# Out:
# array([1, 2, 3, 4])

# %%
np.split(np.array([1,2,3,4]), 2)
# Out:
# [array([1, 2]), array([3, 4])]

# %%
np.size([1,2,3,4])
# Out:
# 4

# %%
np.unique([1,2,2,3])
# Out:
# array([1, 2, 3])

# %%
np.insert([1,2,3],1,10)
# Out:
# array([ 1, 10,  2,  3])

# %%
np.zeros((2,2))
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
np.ones((2,2))
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %%
np.linspace(0,1,5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
np.full((2,2),7)
# Out:
# array([[7, 7],
#        [7, 7]])

# %%
np.random.rand(2,2)
# Out:
# array([[0.8047709 , 0.79377139],
#        [0.39152672, 0.55686283]])

# %%
np.random.randint(1,10,(2,2))
# Out:
# array([[4, 4],
#        [5, 3]])

# %%
np.arange(1,10,2)
# Out:
# array([1, 3, 5, 7, 9])

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.empty((2,2))
# Out:
# array([[0.8047709 , 0.79377139],
#        [0.39152672, 0.55686283]])

# %%
np.array([])
# Out:
# array([], dtype=float64)

# %%
np.reshape([1,2,3,4], (2,2))
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.array([1,2,3,4]).reshape(2,2)
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.transpose([[1,2],[3,4]])
# Out:
# array([[1, 3],
#        [2, 4]])

# %%
np.delete([1,2,3,4], 1)
# Out:
# array([1, 3, 4])

# %%
np.concatenate(([1,2],[3,4]))
# Out:
# array([1, 2, 3, 4])

# %%
np.vstack(([1,2],[3,4]))
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.hstack(([1,2],[3,4]))
# Out:
# array([1, 2, 3, 4])

# %%
np.array([[1,2],[3,4]]).shape
# Out:
# (2, 2)

# %%
np.array([1,2,3]).dtype
# Out:
# dtype('int64')
